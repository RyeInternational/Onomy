# %%
#import packages
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import statistics
import seaborn as sns 

df = pd.read_csv(r"C:\Users\ymf\Desktop\Onomy\coursea_data.csv")
df
# Out:
#      Unnamed: 0                                       course_title  \
# 0           134  (ISC)² Systems Security Certified Practitioner...
# 1           743  A Crash Course in Causality:  Inferring Causal...
# 2           874                     A Crash Course in Data Science
# 3           413                            A Law Student's Toolkit
# 4           635                A Life of Happiness and Fulfillment
# ..          ...                                                ...
# 886         236                         Программирование на Python
# 887         883               Психолингвистика (Psycholinguistics)
# 888         545       Разработка интерфейсов: вёрстка и JavaScript
# 889         875                            Русский как иностранный
# 890         163      Финансовые инструменты для частного инвестора
#
#                                    course_organization  \
# 0                                               (ISC)²
# ...

# %%
df = df[df.course_difficulty == "Beginner"]
df = df[df.course_title.map(lambda x: x.isascii())]
df
# Out:
#      Unnamed: 0                                       course_title  \
# 5           661  ADHD: Everyday Strategies for Elementary Students
# 6            54                                    AI For Everyone
# 8            58                        AI Foundations for Everyone
# 12           43                                   AWS Fundamentals
# 13          631         AWS Fundamentals: Addressing Security Risk
# ..          ...                                                ...
# 864          88                              What is Data Science?
# 866         232  Wine Tasting: Sensory Techniques for Wine Anal...
# 868         619  Write A Feature Length Screenplay For Film Or ...
# 870         684                             Write Your First Novel
# 871          69                            Writing in the Sciences
#
#                  course_organization course_Certificate_type  course_rating  \
# 5              University at Buffalo                  COURSE            4.7
# ...

# %%
personal = df[df['course_title'].str.contains("erson")|df['course_organization'].str.contains("erson")]
#personal, person, Personal all contain erson
r1= personal.shape[0]

p1 = personal["course_students_enrolled"].str[:-1]
p1 = pd.DataFrame(p1)
p1

p1['course_students_enrolled'] = p1['course_students_enrolled'].astype(str).astype(int)
p1.sum()
# Out:
# course_students_enrolled    263
# dtype: int64

# %%
finance = df[df['course_title'].str.contains("Financ")|df['course_organization'].str.contains("Financ")]
#personal, person, Personal all contain erson
r2 = finance.shape[0]
p2 = finance["course_students_enrolled"].str[:-1]
p2 = pd.DataFrame(p2)
p2

p2["course_students_enrolled"] = p2["course_students_enrolled"].astype(str).astype(float)
p2.sum()
# Out:
# course_students_enrolled    1149.1
# dtype: float64

# %%
education = df[df['course_title'].str.contains("Edu")|df['course_organization'].str.contains("Edu")]
#personal, person, Personal all contain erson
r3 = education.shape[0]
p3 = education["course_students_enrolled"].str[:-1]
p3 = pd.DataFrame(p3)
p3

p3["course_students_enrolled"] = p3["course_students_enrolled"].astype(str).astype(float)
p3.sum()
# Out:
# course_students_enrolled    0.0
# dtype: float64

# %%
education = df[df['course_title'].str.contains("Edu")|df['course_organization'].str.contains("Edu")]
education
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, course_title, course_organization, course_Certificate_type, course_rating, course_difficulty, course_students_enrolled]
# Index: []

# %%
account = df[df['course_title'].str.contains("ccount")|df['course_organization'].str.contains("ccount")]
#personal, person, Personal all contain erson
r4 = account.shape[0]
p4 = account["course_students_enrolled"].str[:-1]
p4 = pd.DataFrame(p4)
p4

p4["course_students_enrolled"] = p4["course_students_enrolled"].astype(str).astype(float)
p4.sum()
# Out:
# course_students_enrolled    115.0
# dtype: float64

# %%
account = df[df['course_title'].str.contains("ccount")|df['course_organization'].str.contains("ccount")]
account
# Out:
#      Unnamed: 0                        course_title  \
# 309          85   Financial Accounting Fundamentals
# 343         295          Fundamentals of Accounting
# 575         467  Managerial Accounting Fundamentals
#
#                             course_organization course_Certificate_type  \
# 309                      University of Virginia                  COURSE
# 343  University of Illinois at Urbana-Champaign          SPECIALIZATION
# 575                      University of Virginia                  COURSE
#
#      course_rating course_difficulty course_students_enrolled
# 309            4.8          Beginner                      65k
# 343            4.6          Beginner                      39k
# 575            4.9          Beginner                      11k

# %%
insurance = df[df['course_title'].str.contains("Insurance")|df['course_organization'].str.contains("Insurance")]
#personal, person, Personal all contain erson
r4 = insurance.shape[0]
p4 = insurance["course_students_enrolled"].str[:-1]
p4 = pd.DataFrame(p4)
p4

p4["course_students_enrolled"] = p4["course_students_enrolled"].astype(str).astype(float)
d = 0

for i in range(r4):
    d += p4.iloc[i]
print(d)
# Out:
# 0

# %%
insurance = df[df['course_title'].str.contains("Insurance")|df['course_organization'].str.contains("Insurance")]
insurance
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, course_title, course_organization, course_Certificate_type, course_rating, course_difficulty, course_students_enrolled]
# Index: []

# %%
career = df[df['course_title'].str.contains("areer")|df['course_organization'].str.contains("areer")]
#personal, person, Personal all contain erson
r5 = career.shape[0]
p5 = career["course_students_enrolled"].str[:-1]
p5 = pd.DataFrame(p5)
p5["course_students_enrolled"] = p5["course_students_enrolled"].astype(str).astype(float)
p5.sum()
# Out:
# course_students_enrolled    1230.0
# dtype: float64

# %%
business = df[df['course_title'].str.contains("Business")|df['course_organization'].str.contains("Business")]
#personal, person, Personal all contain erson
r6 = business.shape[0]
p6 = business["course_students_enrolled"].str[:-1]
p6 = pd.DataFrame(p6)
p6
p6["course_students_enrolled"] = p6["course_students_enrolled"].astype(str).astype(float)
print(p6.sum())
# Out:
# course_students_enrolled    3545.9
# dtype: float64

# %%
business = df[df['course_title'].str.contains("Business")|df['course_organization'].str.contains("Business")]
business
# Out:
#      Unnamed: 0                                       course_title  \
# 42          265  An Introduction to Consumer Neuroscience & Neu...
# 99           72  Brand Management: Aligning Business, Brand and...
# 100         238                     Branding: The Creative Journey
# 109          17                                 Business Analytics
# 113           7                               Business Foundations
# 115          96                   Business Statistics and Analysis
# 116         126             Business Strategies for A Better World
# 117         104                                  Business Strategy
# 118         233                     Business Technology Management
# 119         478          Business Transformation with Google Cloud
# 120         539                                   Business Writing
# 121          23                    Business and Financial Modeling
# 183         497                         Cybersecurity for Business
# ...

# %%
adult = df[df['course_title'].str.contains("Adult")|df['course_organization'].str.contains("Adult")]
#personal, person, Personal all contain erson
r7 = adult.shape[0]
p7 = adult["course_students_enrolled"].str[:-1]
p7 = pd.DataFrame(p7)
p7["course_students_enrolled"] = p7["course_students_enrolled"].astype(str).astype(float)
p7.sum()
# Out:
# course_students_enrolled    0.0
# dtype: float64

# %%
pf = pd.merge(personal,finance,how='inner', on=['course_title','course_organization','course_Certificate_type','course_rating','course_difficulty','course_students_enrolled'])
pf
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, course_title, course_organization, course_Certificate_type, course_rating, course_difficulty, course_students_enrolled, Unnamed: 0_y]
# Index: []

# %%
af = pd.merge(account,finance,how='inner', on=['course_title','course_organization','course_Certificate_type','course_rating','course_difficulty','course_students_enrolled'])
af
# Out:
#    Unnamed: 0_x                       course_title     course_organization  \
# 0            85  Financial Accounting Fundamentals  University of Virginia
#
#   course_Certificate_type  course_rating course_difficulty  \
# 0                  COURSE            4.8          Beginner
#
#   course_students_enrolled  Unnamed: 0_y
# 0                      65k            85

# %%
bf = pd.merge(business,finance,how='inner', on=['course_title','course_organization','course_Certificate_type','course_rating','course_difficulty','course_students_enrolled'])
bf
# Out:
#    Unnamed: 0_x                               course_title  \
# 0            23            Business and Financial Modeling
# 1           259  Financial Markets and Investment Strategy
#
#           course_organization course_Certificate_type  course_rating  \
# 0  University of Pennsylvania          SPECIALIZATION            4.5
# 1   Indian School of Business          SPECIALIZATION            4.5
#
#   course_difficulty course_students_enrolled  Unnamed: 0_y
# 0          Beginner                     160k            23
# 1          Beginner                      60k           259

# %%
ba = pd.merge(business,account,how='inner', on=['course_title','course_organization','course_Certificate_type','course_rating','course_difficulty','course_students_enrolled'])
ba
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, course_title, course_organization, course_Certificate_type, course_rating, course_difficulty, course_students_enrolled, Unnamed: 0_y]
# Index: []

# %%
cf = pd.merge(career,finance,how='inner', on=['course_title','course_organization','course_Certificate_type','course_rating','course_difficulty','course_students_enrolled'])
cf
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, course_title, course_organization, course_Certificate_type, course_rating, course_difficulty, course_students_enrolled, Unnamed: 0_y]
# Index: []

# %%
cb = pd.merge(career,business,how='inner', on=['course_title','course_organization','course_Certificate_type','course_rating','course_difficulty','course_students_enrolled'])
cb
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, course_title, course_organization, course_Certificate_type, course_rating, course_difficulty, course_students_enrolled, Unnamed: 0_y]
# Index: []

# %%
pc = pd.merge(career,personal,how='inner', on=['course_title','course_organization','course_Certificate_type','course_rating','course_difficulty','course_students_enrolled'])
pc
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, course_title, course_organization, course_Certificate_type, course_rating, course_difficulty, course_students_enrolled, Unnamed: 0_y]
# Index: []

# %%
ca = pd.merge(career,account,how='inner', on=['course_title','course_organization','course_Certificate_type','course_rating','course_difficulty','course_students_enrolled'])
ca
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, course_title, course_organization, course_Certificate_type, course_rating, course_difficulty, course_students_enrolled, Unnamed: 0_y]
# Index: []

# %%
plotdata = pd.DataFrame(
    {"# of subscribers(units:million)": [263/1000,1149.1/1000,115/1000,1230/1000,3545.9/1000]}, 
    index=["personal", "finance", "accounting", "career", "business"])
# Plot a bar chart
plotdata.plot(kind="bar")
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Coursera: Number of Subscibers of Relevant Courses at Beginners Level")
plt.xlabel("Categories")
plt.ylabel("Total number of subscribers(in million)")
# Out:
# Text(0, 0.5, 'Total number of subscribers(in million)')

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
# Custom text labels: change the label of group A
v=venn3(subsets = (782.1,30,85,3263.9,282,0,0), set_labels = ('finance', 'accounting', 'business'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-76cbca2397de> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 from matplotlib_venn import venn3
#       3 # Custom text labels: change the label of group A
#       4 v=venn3(subsets = (782.1,30,85,3263.9,282,0,0), set_labels = ('finance', 'accounting', 'business'))
#       5 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib_venn'
