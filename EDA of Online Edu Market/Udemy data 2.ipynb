# %%
# %matplotlib inline
#import packages
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import statistics
import seaborn as sns
df = pd.read_csv(r"C:\Users\jim13\Documents\project1\udemy.csv")
df.drop("id",axis=1,inplace=True)
df.drop("avg_rating_recent",axis=1,inplace=True)
df.drop("is_paid",axis=1,inplace=True)
df.drop("url",axis=1,inplace=True)
df.drop("avg_rating",axis=1,inplace=True)
df.drop("num_published_practice_tests",axis=1,inplace=True)
df.drop("created",axis=1,inplace=True)
df.drop("published_time",axis=1,inplace=True)
df.drop("discount_price__amount",axis=1,inplace=True)
df.drop("discount_price__currency",axis=1,inplace=True)
df.drop("discount_price__price_string",axis=1,inplace=True)
df.drop("price_detail__currency",axis=1,inplace=True)
df.drop("price_detail__price_string",axis=1,inplace=True)
df.drop("is_wishlisted",axis=1,inplace=True)

df.head(99)
# Out:
#                                                 title  num_subscribers  \
# 0   The Complete SQL Bootcamp 2020: Go from Zero t...           295509
# 1   Tableau 2020 A-Z: Hands-On Tableau Training fo...           209070
# 2              PMP Exam Prep Seminar -  PMBOK Guide 6           155282
# 3          The Complete Financial Analyst Course 2020           245860
# 4   An Entire MBA in 1 Course:Award Winning Busine...           374836
# ..                                                ...              ...
# 94  Project Management: Master Project Management ...            13693
# 95                     Seth Godin's Freelancer Course            24449
# 96  PMI-ACP Agile Certified Exam Prep - PMI REP 21...            16519
# 97  Master Course in Tableau 10 & 2020 for Busines...            18774
# 98  Management Skills - Team Leadership Skills Mas...            25911
#
#      rating  num_reviews  num_published_lectures  price_detail__amount
# ...

# %%
personal = df[df['title'].str.contains("Personal")|df['title'].str.contains("personal")]
print(personal.shape)
personal.head()
# Out:
# (188, 6)
#                                                   title  num_subscribers  \
# 77    The Complete Personal Finance Course: Save,Pro...            87181
# 408             Understanding Personality Types at Work             5662
# 531   Communication Skills: Personality and Behaviou...             4600
# 661   Personal Development Life Coach Certification1...             4255
# 1078         Raising Angel Capital: Your Personal Brand            11918
#
#        rating  num_reviews  num_published_lectures  price_detail__amount
# 77    4.58665         5018                     122                8640.0
# 408   4.36929         1192                      21                8000.0
# 531   4.49556          874                      76                8640.0
# 661   4.01147          712                      93                8640.0
# 1078  4.46211          379                      18                1280.0

# %%
accounting = df[df['title'].str.contains("Accounting")|df['title'].str.contains("accounting")]
print(accounting.shape)
accounting.head()
# Out:
# (418, 6)
#                                                  title  num_subscribers  \
# 22   Introduction to Finance, Accounting, Modeling ...           140676
# 43     Accounting in 60 Minutes - A Brief Introduction            79955
# 61   Accounting & Financial Statement Analysis: Com...            37953
# 188  Accounting - A Brief Introduction - in 60 Minutes            26516
# 232  Financial Accounting - #1 Ranked University: C...            20308
#
#       rating  num_reviews  num_published_lectures  price_detail__amount
# 22   4.46916        17013                      61                9280.0
# 43   4.50644         9107                      16                2240.0
# 61   4.57075         6195                      54                8640.0
# 188  4.61348         2506                      17                1920.0
# 232  4.58394         2126                      60                9600.0

# %%
business = df[df['title'].str.contains("Business")|df['title'].str.contains("business")]
print(business.shape)
business.head()
# Out:
# (1519, 6)
#                                                 title  num_subscribers  \
# 4   An Entire MBA in 1 Course:Award Winning Busine...           374836
# 9       The Business Intelligence Analyst Course 2020           115269
# 11                     Business Analysis Fundamentals            82015
# 14  SQL - MySQL for Data Analytics and Business In...            78968
# 49          MBA in a Box: Business Lessons from a CEO            44484
#
#      rating  num_reviews  num_published_lectures  price_detail__amount
# 4   4.47173        41630                      83                8640.0
# 9   4.49575        23906                     413                8640.0
# 11  4.49034        23326                      67                8640.0
# 14  4.57067        21436                     286                8640.0
# 49  4.53498         7815                     186                8640.0

# %%
finance = df[df['title'].str.contains("Finance")|df['title'].str.contains("finance")]
print(finance.shape)
finance.head()
# Out:
# (372, 6)
#                                                  title  num_subscribers  \
# 20   Python for Finance: Investment Fundamentals & ...            83072
# 22   Introduction to Finance, Accounting, Modeling ...           140676
# 77   The Complete Personal Finance Course: Save,Pro...            87181
# 186           The Complete Finance Manager Course 2020            17758
# 286      Finance for Non-Finance: Learn Quick and Easy             9179
#
#       rating  num_reviews  num_published_lectures  price_detail__amount
# 20   4.52806        17617                     111                8640.0
# 22   4.46916        17013                      61                9280.0
# 77   4.58665         5018                     122                8640.0
# 186  4.46792         2529                     244                8640.0
# 286  4.39435         1780                      30                1280.0

# %%
education = df[df['title'].str.contains("Education")|df['title'].str.contains("education")]
print(education.shape)
education.head()
# Out:
# (9, 6)
#                                                    title  num_subscribers  \
# 2258   Business Education: Guide to Blockchain and Cr...            25295
# 3196   Forex Trading Education: Learn from A to Z wit...              384
# 6015          Public Speaking for Business and Education             1651
# 9306                  Economics - Super Simple Education               15
# 10103  Credit Education, Credit Reports and FICO Scoring               69
#
#         rating  num_reviews  num_published_lectures  price_detail__amount
# 2258   4.20709          119                      43                1920.0
# 3196   4.83832           67                      26                8640.0
# 6015   3.24984           19                      25                5120.0
# 9306   3.85844            3                      11                1280.0
# 10103  4.25877           17                      82                3200.0

# %%
tax = df[df['title'].str.contains("Tax")|df['title'].str.contains("tax")]
print(tax.shape)
tax.head()
# Out:
# (122, 6)
#                                                   title  num_subscribers  \
# 450      Tax Preparation and Law 2019 2020 - Income Tax             7797
# 1436  Tax Preparation: Learn Fast! Prepare Taxes wit...             1593
# 1546     Direct Taxation in India A Comprehensive Study              963
# 1758                     Fundamentals of Business Taxes             1171
# 1823         Practical Course in Goods and Services Tax              628
#
#        rating  num_reviews  num_published_lectures  price_detail__amount
# 450   4.36982         1062                     431                8640.0
# 1436  3.77874          243                      33                8640.0
# 1546  4.23626          220                     379                8640.0
# 1758  4.47023          178                      17                1280.0
# 1823  4.10520          169                      78                4160.0

# %%
invest = df[df['title'].str.contains("Invest")|df['title'].str.contains("invest")]
print(invest.shape)
invest.head()
# Out:
# (678, 6)
#                                                  title  num_subscribers  \
# 15   The Complete Financial Analyst Training & Inve...           182002
# 17         The Complete Investment Banking Course 2020            88468
# 20   Python for Finance: Investment Fundamentals & ...            83072
# 47   Fundamentals of Analyzing Real Estate Investments            64080
# 144  Stock Trading & Investing for Beginners 4-in-1...            16406
#
#       rating  num_reviews  num_published_lectures  price_detail__amount
# 15   4.49507        21421                     225                8640.0
# 17   4.48929        19970                     160                8640.0
# 20   4.52806        17617                     111                8640.0
# 47   4.43577         8591                     152                8960.0
# 144  4.21029         3217                     120                8640.0

# %%
credit = df[df['title'].str.contains("Credit")|df['title'].str.contains("credit")]
print(credit.shape)
credit.head()
# Out:
# (94, 6)
#                                                  title  num_subscribers  \
# 91   Six Sigma Green Belt (With Excel Application) ...            14692
# 114  Lean Management For All Sectors (Dutch BKO Acc...            12864
# 242                Credit Risk Modeling in Python 2020             8568
# 309        Six Sigma White Belt (Dutch BKO Accredited)             4887
# 324                 The Credit Analyst Training course             6688
#
#       rating  num_reviews  num_published_lectures  price_detail__amount
# 91   4.42271         4554                      49                8640.0
# 114  4.57774         3672                      37                8640.0
# 242  4.53305         2081                      75                8640.0
# 309  4.51484         1625                      12                8640.0
# 324  4.26229         1551                      61                4800.0

# %%
career = df[df['title'].str.contains("Career")|df['title'].str.contains("career")]
print(career.shape)
career.head()
# Out:
# (64, 6)
#                                                  title  num_subscribers  \
# 32   Tableau for Beginners: Get CA Certified, Grow ...            39873
# 216  2019 Blog Blueprint: How To Turn Blogging Into...            19030
# 223  Learn HR Fundamentals for a Career in Human Re...             5604
# 289  Customer Success Manager: Fundamentals to your...            11396
# 676  How to be an Expert in Piping Components for O...             3704
#
#       rating  num_reviews  num_published_lectures  price_detail__amount
# 32   4.49998        10725                     124                2560.0
# 216  4.21770         2233                      50                8640.0
# 223  4.37929         2187                      17                6400.0
# 289  4.69311         1769                      28                3200.0
# 676  4.09176          695                      65                9280.0

# %% [markdown]
# ### Summary
# #### Sample Size: 1040 Courses for Beginner/All Levels
# - personal: 188
# - accounting: 418
# - business: 1519
# - finance: 372
# - education: 9
# - tax: 122
# - invest: 678
# - credit: 94
# - career: 64

# %%
plotdata = pd.DataFrame(
 {"# of courses": [
188,
418,
1519,
372,
9,
122,
678,
94,
64]},
 index=["personal","accounting","business","finance","education","tax","invest","credit","career"])
# Plot a bar chart
plotdata.plot(kind="bar")
plt.xticks(rotation=25, horizontalalignment="center")
plt.title("Number of Revelant Courses for Beginners/All Levels")
plt.xlabel("Key Words in Course Title")
plt.ylabel("Number of Courses provided")
# Out:
# Text(0, 0.5, 'Number of Courses provided')

# %%
sns.set_style('white')
sns.set_style('ticks')

sns.regplot(x="num_reviews",y="num_subscribers",data=df)
# Out:
# <AxesSubplot:xlabel='num_reviews', ylabel='num_subscribers'>

# %%
sns.regplot(x="rating",y="num_subscribers",data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='num_subscribers'>

# %%
df["price_detail__amount"] = [x*0.013 for x in df["price_detail__amount"]]
df.head()
# Out:
#                                                title  num_subscribers  \
# 0  The Complete SQL Bootcamp 2020: Go from Zero t...           295509
# 1  Tableau 2020 A-Z: Hands-On Tableau Training fo...           209070
# 2             PMP Exam Prep Seminar -  PMBOK Guide 6           155282
# 3         The Complete Financial Analyst Course 2020           245860
# 4  An Entire MBA in 1 Course:Award Winning Busine...           374836
#
#     rating  num_reviews  num_published_lectures  price_detail__amount
# 0  4.67874        78006                      84                112.32
# 1  4.60015        54581                      78                112.32
# 2  4.59326        52653                     292                112.32
# 3  4.53772        46447                     338                112.32
# 4  4.47173        41630                      83                112.32

# %%
df.plot.scatter(x="price_detail__amount",y="num_subscribers")
plt.xticks(rotation=90, horizontalalignment="center")
plt.title("The effect of Price on number of Subscribers")
plt.xlabel("Price")
plt.ylabel("Number of Subscribers")
# Out:
# Text(0, 0.5, 'Number of Subscribers')

# %%
sns.regplot(x="num_published_lectures",y="num_subscribers",data=df)
plt.title("The effect of number of Lectures on number of Subscribers")
# Out:
# Text(0.5, 1.0, 'The effect of number of Lectures on number of Subscribers')

# %%
sns.boxplot(x='num_subscribers',data=df)
# Out:
# <AxesSubplot:xlabel='num_subscribers'>

# %%
sns.boxplot(x='rating',data=df)
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
df.sort_values('num_subscribers',ascending=False)
# Out:
#                                                    title  num_subscribers  \
# 4      An Entire MBA in 1 Course:Award Winning Busine...           374836
# 0      The Complete SQL Bootcamp 2020: Go from Zero t...           295509
# 11484               Stock Market Investing for Beginners           259888
# 3             The Complete Financial Analyst Course 2020           245860
# 19     Deep Learning Prerequisites: The Numpy Stack i...           239309
# ...                                                  ...              ...
# 13242   TECHNOLOGIE DER ZUKUNFT - DER SMARTER AUFSTELLER                0
# 13241  Quais medidas contábeis adotar em tempos de crise                0
# 13240               Comment créer un budget prévisionnel                0
# 11219                      Increasing Your Net Cash Flow                0
# 13607         Acabou a Previdência e agora? -  Volume 03                0
#
#         rating  num_reviews  num_published_lectures  price_detail__amount
# ...

# %%
df.sort_values('rating',ascending=False)
# Out:
#                                                    title  num_subscribers  \
# 12875  Bolsa de Valores: Os segredos do mercado de ações                3
# 11043  Tax Saver Series (Standard Vs. Itemized) Deduc...               11
# 11029                     Transforming the Public Sector                5
# 11033  The Complete Scalping S&P500 Course on Real Tr...               13
# 11036  Health Plan Finance and Risk Management - Prac...                5
# ...                                                  ...              ...
# 11375           WEALTH CODED FREQUENCIES (THE MIND HACK)                3
# 11376  Capital Budgeting – The  Investment and Financ...                2
# 11377   What you need to know about forex (step by step)               10
# 11378                            ACI Dealing Certificate                5
# 13607         Acabou a Previdência e agora? -  Volume 03                0
#
#        rating  num_reviews  num_published_lectures  price_detail__amount
# ...

# %%
personal = df[df['title'].str.contains("Trading Penny Stocks")]
print(personal.shape)
personal.head()
# Out:
# (4, 6)
#                                                    title  num_subscribers  \
# 956         Start Day Trading Penny Stocks in 60 Minutes             3032
# 1383   Need Money? Day Trading Penny Stocks With Litt...             2116
# 10077  Learning The Psychology Of Day Trading Penny S...             1570
# 10085  Trading Penny Stocks 101: Big profits with sma...               66
#
#         rating  num_reviews  num_published_lectures  price_detail__amount
# 956    4.53315          446                      16                 29.12
# 1383   4.53416          257                      17                 29.12
# 10077  3.58193           18                       7                112.32
# 10085  4.50266           18                      13                 16.64
